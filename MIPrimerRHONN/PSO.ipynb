# %% [markdown]
# # PSO intento 1

# %%
# !pip install --upgrade pyswarm
# Out:
# Collecting pyswarm
#   Downloading pyswarm-0.6.tar.gz
# Requirement already up-to-date: numpy in /Users/MichelMacSDD/anaconda/lib/python3.5/site-packages (from pyswarm)
# Building wheels for collected packages: pyswarm
#   Running setup.py bdist_wheel for pyswarm ... done
#   Stored in directory: /Users/MichelMacSDD/Library/Caches/pip/wheels/a8/e9/bc/37ea1dd918cc28bad116868baa963193d0a8b8b962a8ca8a5d
# Successfully built pyswarm
# Installing collected packages: pyswarm
# Successfully installed pyswarm-0.6

# %%
#%matplotlib inline
# %matplotlib notebook
import matplotlib.pylab as plt
import numpy as np

# %%
from pyswarm import pso

def banana(x):
    x1 = x[0]
    x2 = x[1]
    return x1**4 - 2*x2*x1**2 + x2**2 + x1**2 - 2*x1 + 5

def con(x):
    x1 = x[0]
    x2 = x[1]
    return [-(x1 + 0.25)**2 + 0.75*x2]

lb = [-3, -1]
ub = [2, 6]

xopt, fopt = pso(banana, lb, ub, f_ieqcons=con)
# Out:
# Stopping search: Swarm best objective change less than 1e-08

# %%
xopt,fopt
# Out:
# (array([ 0.48996269,  0.73005972]), 4.5002344158290839)

# %% [markdown]
# # Intento $x^2$

# %%
def cuad(x):
    return x**2 +20

x = np.arange(-10,10,.1)
plt.plot(x,cuad(x))
# Out:
# <img src="data:image/png;base64,...">

# %%
# Define the lower and upper bounds for H, d, t, respectively
lb = [-10]
ub = [10]

xopt, fopt = pso(cuad,lb,ub)
# Out:
# Stopping search: Swarm best objective change less than 1e-08

# %%
xopt,fopt
# Out:
# (array([  8.50427872e-06]), array([ 20.]))

# %% [markdown]
# ## Ahora una $X^2 + Y^2$

# %%
def cuad(x):
    x1 = x[0]
    x2 = x[1]
    return x1**2 + x2**2 + 20

#x = np.arange(-10,10,.1)
#plt.plot(x,cuad(x))

# %%
# Define the lower and upper bounds for H, d, t, respectively
lb = [-3, -1]
ub = [2, 6]

xopt, fopt = pso(cuad,lb,ub)
# Out:
# Stopping search: Swarm best objective change less than 1e-08

# %%
xopt,fopt
# Out:
# (array([  1.07302851e-05,  -3.55531461e-05]), 20.000000001379163)

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# Silly example data
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
Z = X**2 + Y**2 + 20

# Make the plot
fig = plt.figure()
ax = fig.gca(projection="3d")
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
#ax.set_zlim(-1.01, 1.01)
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()
# Out:
# <img src="data:image/png;base64,...">
